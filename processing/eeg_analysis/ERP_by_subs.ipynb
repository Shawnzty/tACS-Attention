# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))
from scipy.io import loadmat
from pathlib import Path
import matplotlib.patches as patches
import matplotlib.lines as mlines
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib.image as mpimg
import numpy as np
import pandas as pd
# the following import is required for matplotlib < 3.2:
from mpl_toolkits.mplot3d import Axes3D  # noqa
from scipy import stats
import mne
import eeg_analysis.funcs4eeg as fe
import re
import imp
import ast
import behavior.func4behav as fb
imp.reload(fe)
imp.reload(fb)
# Out:
# <module 'behavior.func4behav' from 'c:\\Users\\Tianyi Zheng\\OneDrive - neuron.t.u-tokyo.ac.jp\\Documents\\zheng\\mywork\\attention_tES\\tes-attention\\processing\\behavior\\func4behav.py'>

# %%
case = 'endo valid'
watch='11 stim'
tmin = -0.1
tmax = 0.5

sham_evoked_before, sham_evoked_after, real_evoked_before, real_evoked_after, _, _ = fe.pipeline_ERP_bysubs(case, watch, tmin, tmax, hipass=30)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,
# Filtering raw data in 1 contiguous segment
# Setting up low-pass filter at 30 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal lowpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Upper passband edge: 30.00 Hz
# - Upper transition bandwidth: 7.50 Hz (-6 dB cutoff frequency: 33.75 Hz)
# - Filter length: 529 samples (0.441 sec)
# c:\ProgramData\anaconda3\envs\mne\lib\site-packages\mne\filter.py:312: DeprecationWarning: Keyword argument 'nyq' is deprecated in favour of 'fs' and will be removed in SciPy 1.12.0.
#   this_h = firwin(this_N, (prev_freq + this_freq) / 2.,

# %%
# remove bad channels
real_ids = [1, 3, 4, 5, 9, 12, 13, 17, 18]
sham_ids = [2, 6, 7, 8, 10, 11, 14, 15, 16]
group_id = 5
subject_id = real_ids[group_id]
real_evoked_after[group_id].plot(spatial_colors=True, gfp=True, time_unit='ms', titles = 'real after:'+str(subject_id), hline=[0], exclude=['Fz'])

# %%
for i in range(9):
    real_evoked_after[i].plot(spatial_colors=True, gfp=True, time_unit='ms', titles = 'real after:'+str(i), hline=[0])

# %% [markdown]
# ### Compare

# %%
bad_channels = [
        [ # sham
            [], [], [], [], [], [], ['P7','P5'], ['F7','F8'], []
        ],
        [ # real
            [], [], [], [], [], ['Fz'], [], [], []
        ]
]
image_paths = []
channels = fe.pick_cortex('parietal, anode, cathode')

# Sham
for group_id in range(9):
    evokeds = {"Before": sham_evoked_before[group_id], "After": sham_evoked_after[group_id]}
    
    picks = list(channels.keys())
    
    picks = [item for item in picks if item not in bad_channels[0][group_id]]
    
    # Save the plot to a file
    fig = mne.viz.plot_compare_evokeds(evokeds, combine="mean", title="sham: " + str(group_id), 
                                       show_sensors="lower right", picks=picks, show=False, colors=['lightblue', 'blue'])
    
    image_path = os.path.join('tmp_files', f"temp_plot_{group_id}.png")
    fig[0].savefig(image_path)
    image_paths.append(image_path)  # This line is corrected
    plt.close(fig[0])

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Initialize the 3x3 grid of subplots
fig, axs = plt.subplots(3, 3, figsize=(15, 15))

for idx, ax in enumerate(axs.ravel()):
    img = mpimg.imread(image_paths[idx])
    ax.imshow(img)
    ax.axis('off')  # Turn off axis numbers and ticks


# Adjust the spacing between the subplots
plt.subplots_adjust(wspace=0, hspace=0)

plt.show()
# Out:
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"

# %%
bad_channels = [
        [ # sham
            [], [], [], [], [], [], ['P7','P5'], ['F7','F8'], []
        ],
        [ # real
            [], [], [], [], [], ['Fz'], [], [], []
        ]
]
image_paths = []

# Sham
for group_id in range(9):
    evokeds = {"Before": real_evoked_before[group_id], "After": real_evoked_after[group_id]}
    
    picks = list(channels.keys())
    
    picks = [item for item in picks if item not in bad_channels[0][group_id]]
    
    # Save the plot to a file
    fig = mne.viz.plot_compare_evokeds(evokeds, combine="mean", title="sham: " + str(group_id), 
                                       show_sensors="lower right", picks=picks, show=False, colors=['lightcoral', 'red'])
    
    image_path = os.path.join('tmp_files', f"temp_plot_{group_id}.png")
    fig[0].savefig(image_path)
    image_paths.append(image_path)  # This line is corrected
    plt.close(fig[0])

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Initialize the 3x3 grid of subplots
fig, axs = plt.subplots(3, 3, figsize=(15, 15))

for idx, ax in enumerate(axs.ravel()):
    img = mpimg.imread(image_paths[idx])
    ax.imshow(img)
    ax.axis('off')  # Turn off axis numbers and ticks


# Adjust the spacing between the subplots
plt.subplots_adjust(wspace=0, hspace=0)

plt.show()
# Out:
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"

# %%
# real
for group_id in range(9):
    evokeds = {"Before": real_evoked_before[group_id], "After": real_evoked_after[group_id]}
    
    picks = list(channels.keys())
    
    picks = [item for item in picks if item not in bad_channels[1][group_id]]
    
    # Save the plot to a file
    fig = mne.viz.plot_compare_evokeds(evokeds, combine="mean", title="real: " + str(group_id), 
                                       show_sensors="lower right", picks=picks, show=False, colors=['lightcoral', 'red'])
    image_path = os.path.join('tmp_files', f"temp_plot_{group_id}.png")
    fig[0].savefig(image_path)
    image_paths.append(image_path)
    plt.close(fig[0])


# Initialize the 3x3 grid of subplots
fig, axs = plt.subplots(3, 3, figsize=(15, 15))

for idx, ax in enumerate(axs.ravel()):
    image_path = os.path.join('tmp_files', f"temp_plot_{group_id}.png")
    img = mpimg.imread(image_paths[idx])
    ax.imshow(img)
    ax.axis('off')  # Turn off axis numbers and ticks

# Adjust the spacing between the subplots
plt.subplots_adjust(wspace=0, hspace=0)

plt.show()
# Out:
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"
# combining channels using "mean"

# %% [markdown]
# ### compare by substract?
